# %% [markdown]
# ### **Image Captioning with Text to speech translation**

# %%
import os
import zipfile
import string
import numpy as np
import pandas as pd
from collections import defaultdict

# %%
# Paths to dataset files
images_zip = "Flickr8k_Dataset.zip"
text_zip = "Flickr8k_text.zip"

data_dir = "./Flickr8k_Dataset"
text_dir = "./Flickr8k_text"

# %%
# Extract images
if not os.path.exists(data_dir):
    with zipfile.ZipFile(images_zip, 'r') as zip_ref:
        zip_ref.extractall(".")

# Extract text files
if not os.path.exists(text_dir):
    with zipfile.ZipFile(text_zip, 'r') as zip_ref:
        zip_ref.extractall(".")

# %%
# Load captions file
captions_file = "./Flickr8k.token.txt"
with open(captions_file, "r") as file:
    captions = file.readlines()

# Process captions
def process_caption(caption):
    caption = caption.lower().strip()
    caption = caption.translate(str.maketrans("", "", string.punctuation))  # Remove punctuation
    caption = "startseq " + caption + " endseq"  # Add start and end tokens
    return caption

# %%
# Mapping images to captions
image_captions = defaultdict(list)
for line in captions:
    img, caption = line.split("\t")
    img = img.split("#")[0]
    processed_caption = process_caption(caption)
    image_captions[img].append(processed_caption)

# Select first 1000 images for training
image_list = sorted(image_captions.keys())[:1000]
image_captions = {img: image_captions[img] for img in image_list}

# %%
# Save to a DataFrame for easy access
df = pd.DataFrame([(img, cap) for img, caps in image_captions.items() for cap in caps], columns=["image", "caption"])

# Save processed captions to a CSV file
df.to_csv("processed_captions.csv", index=False)

# %%
import pickle
from collections import defaultdict
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.models import Model

# %%
# Feature Extraction using ResNet50
model = ResNet50(weights='imagenet')
model = Model(inputs=model.input, outputs=model.layers[-2].output)  # Remove last classification layer

features = {}

for img_name in image_list:
    img_path = os.path.join(data_dir, img_name)
    if os.path.exists(img_path):
        img = load_img(img_path, target_size=(224, 224))  # Resize image to 224x224
        img = img_to_array(img)
        img = np.expand_dims(img, axis=0)
        img = preprocess_input(img)
        feature = model.predict(img, verbose=0)
        features[img_name] = feature.flatten()

with open("captions.pkl", "wb") as f:
    pickle.dump(image_captions, f)

# Save extracted features
with open("image_features.pkl", "wb") as f:
    pickle.dump(features, f)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels.h5
# 102967424/102967424 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from collections import Counter

# Text Preprocessing
all_captions = [cap for caps in image_captions.values() for cap in caps]

# Build vocabulary
word_counts = Counter()
for caption in all_captions:
    word_counts.update(caption.split())

vocab_threshold = 5  # Keep words appearing at least 5 times
vocab = [word for word, count in word_counts.items() if count >= vocab_threshold]

# %%
# Tokenization
tokenizer = Tokenizer()
tokenizer.fit_on_texts(vocab)
vocab_size = len(tokenizer.word_index) + 1  # Include padding index

# Convert captions to sequences
sequences = tokenizer.texts_to_sequences(all_captions)

# Padding to ensure uniform length
max_length = max(len(seq) for seq in sequences)
padded_sequences = pad_sequences(sequences, maxlen=max_length, padding='post')

# Save tokenizer and processed sequences
with open("tokenizer.pkl", "wb") as f:
    pickle.dump(tokenizer, f)

with open("padded_sequences.pkl", "wb") as f:
    pickle.dump(padded_sequences, f)

# %%
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import LSTM, Embedding, Dense, Dropout, Add, Input
from tensorflow.keras.utils import to_categorical
import tensorflow as tf

# %%
# !wget http://nlp.stanford.edu/data/glove.6B.zip
# !unzip glove.6B.zip

# Load pre-trained GloVe embeddings
def load_glove_embeddings(filepath="glove.6B.200d.txt", embedding_dim=200):
    embeddings_index = {}
    with open(filepath, encoding="utf-8") as f:
        for line in f:
            values = line.split()
            word = values[0]
            coefs = np.asarray(values[1:], dtype='float32')
            embeddings_index[word] = coefs
    return embeddings_index

glove_embeddings = load_glove_embeddings()

embedding_matrix = np.zeros((vocab_size, 200))
for word, i in tokenizer.word_index.items():
    embedding_vector = glove_embeddings.get(word)
    if embedding_vector is not None:
        embedding_matrix[i] = embedding_vector
# Out:
# --2025-03-09 15:13:48--  http://nlp.stanford.edu/data/glove.6B.zip
# Resolving nlp.stanford.edu (nlp.stanford.edu)... 171.64.67.140
# Connecting to nlp.stanford.edu (nlp.stanford.edu)|171.64.67.140|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://nlp.stanford.edu/data/glove.6B.zip [following]
# --2025-03-09 15:13:48--  https://nlp.stanford.edu/data/glove.6B.zip
# Connecting to nlp.stanford.edu (nlp.stanford.edu)|171.64.67.140|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://downloads.cs.stanford.edu/nlp/data/glove.6B.zip [following]
# --2025-03-09 15:13:48--  https://downloads.cs.stanford.edu/nlp/data/glove.6B.zip
# Resolving downloads.cs.stanford.edu (downloads.cs.stanford.edu)... 171.64.64.22
# Connecting to downloads.cs.stanford.edu (downloads.cs.stanford.edu)|171.64.64.22|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 862182613 (822M) [application/zip]
# Saving to: ‘glove.6B.zip’
#
# glove.6B.zip        100%[===================>] 822.24M  5.06MB/s    in 2m 40s
#
# 2025-03-09 15:16:29 (5.13 MB/s) - ‘glove.6B.zip’ saved [862182613/862182613]
#
# Archive:  glove.6B.zip
#   inflating: glove.6B.50d.txt
#   inflating: glove.6B.100d.txt
#   inflating: glove.6B.200d.txt
#   inflating: glove.6B.300d.txt

# %%
# Define Encoder-Decoder Model
embedding_dim = 200

def define_model():
    # Image feature input
    image_input = Input(shape=(2048,))
    image_fc = Dense(256, activation='relu')(image_input) 

    # Text input
    text_input = Input(shape=(max_length,))
    text_embedding = Embedding(vocab_size, embedding_dim, weights=[embedding_matrix], trainable=False)(text_input)
    text_lstm = LSTM(256, return_sequences=True)(text_embedding)
    text_lstm = LSTM(256)(text_lstm)

    # Merging image and text features
    decoder = Add()([image_fc, text_lstm])
    decoder = Dense(256, activation='relu')(decoder)
    output = Dense(vocab_size, activation='softmax')(decoder)

    model = tf.keras.Model(inputs=[image_input, text_input], outputs=output)
    model.compile(loss='categorical_crossentropy', optimizer='adam')
    return model

model = define_model()
print(model.summary())
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2             │ (None, 34)             │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ embedding (Embedding)     │ (None, 34, 200)        │        182,400 │ input_layer_2[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ input_layer_1             │ (None, 2048)           │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lstm (LSTM)               │ (None, 34, 256)        │        467,968 │ embedding[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense (Dense)             │ (None, 256)            │        524,544 │ input_layer_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lstm_1 (LSTM)             │ (None, 256)            │        525,312 │ lstm[0][0]             │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add (Add)                 │ (None, 256)            │              0 │ dense[0][0],           │
# │                           │                        │                │ lstm_1[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_1 (Dense)           │ (None, 256)            │         65,792 │ add[0][0]              │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_2 (Dense)           │ (None, 912)            │        234,384 │ dense_1[0][0]          │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 2,000,400 (7.63 MB)
#  Trainable params: 1,818,000 (6.94 MB)
#  Non-trainable params: 182,400 (712.50 KB)
# None

# %%
# !pip install gTTS
# Out:
# Collecting gTTS
#   Downloading gTTS-2.5.4-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.11/dist-packages (from gTTS) (2.32.3)
# Requirement already satisfied: click<8.2,>=7.1 in /usr/local/lib/python3.11/dist-packages (from gTTS) (8.1.8)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->gTTS) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->gTTS) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->gTTS) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->gTTS) (2025.1.31)
# Downloading gTTS-2.5.4-py3-none-any.whl (29 kB)
# Installing collected packages: gTTS
# Successfully installed gTTS-2.5.4

# %%
import random
import numpy as np
import pickle
import tensorflow as tf
from nltk.translate.bleu_score import corpus_bleu
from gtts import gTTS
import os
import cv2
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical

# Load processed data
with open("tokenizer.pkl", "rb") as f:
    tokenizer = pickle.load(f)

with open("image_features.pkl", "rb") as f:
    image_features = pickle.load(f)

# Assuming image_captions is available from previous steps:
with open("captions.pkl", "wb") as f:
    pickle.dump(image_captions, f)

with open("captions.pkl", "rb") as f:
    captions = pickle.load(f)

vocab_size = len(tokenizer.word_index) + 1
max_length = 34

# Splitting data (80% train, 20% validation)
image_ids = list(captions.keys())
train_ids, val_ids = train_test_split(image_ids, test_size=0.2, random_state=42)

# **Fixed Data Generator**
def data_generator(image_ids, captions, tokenizer, max_length, batch_size=32):
    while True:
        random.shuffle(image_ids)
        for i in range(0, len(image_ids), batch_size):
            batch_ids = image_ids[i:i+batch_size]
            X_img, X_seq, y = [], [], []

            for img_id in batch_ids:
                if img_id not in image_features:
                    print(f"⚠️ Warning: {img_id} not found in image_features. Skipping...")
                    continue  # Skip missing image features

                img_feature = image_features[img_id]

                # Ensure image feature has correct shape
                if img_feature.shape != (2048,):
                    print(f"⚠️ Warning: {img_id} has incorrect shape {img_feature.shape}, expected (2048,). Skipping...")
                    continue  # Skip incorrectly shaped images

                for caption in captions[img_id]:
                    seq = tokenizer.texts_to_sequences([caption])[0]

                    for j in range(1, len(seq)):
                        in_seq, out_seq = seq[:j], seq[j]

                        in_seq = pad_sequences([in_seq], maxlen=max_length, padding='post')[0]
                        out_seq = to_categorical(out_seq, num_classes=vocab_size, dtype='float32')

                        X_img.append(img_feature)
                        X_seq.append(in_seq)
                        y.append(out_seq)

            # **Fix: Ensure batch is not empty before yielding**
            if len(X_img) == 0:
                print("⚠️ Skipping empty batch...")
                continue  # Skip empty batches

            yield (
                (np.array(X_img, dtype=np.float32), np.array(X_seq, dtype=np.int32)),
                np.array(y, dtype=np.float32)
            )

model = define_model()

# %%
batch_size = 32
# **Define Output Signature**
output_signature = (
    (
        tf.TensorSpec(shape=(None, 2048), dtype=tf.float32),
        tf.TensorSpec(shape=(None, max_length), dtype=tf.int32)
    ),
    tf.TensorSpec(shape=(None, vocab_size), dtype=tf.float32)
)

# **Create Training Dataset**
train_dataset = tf.data.Dataset.from_generator(
    lambda: data_generator(train_ids, captions, tokenizer, max_length, batch_size),
    output_signature=output_signature
)

# **Create Validation Dataset**
val_dataset = tf.data.Dataset.from_generator(
    lambda: data_generator(val_ids, captions, tokenizer, max_length, batch_size),
    output_signature=output_signature
)

# %%
# **Train Model**
history = model.fit(
    train_dataset,
    epochs=20,
    steps_per_epoch=max(1, len(train_ids) // batch_size),
    validation_data=val_dataset,
    validation_steps=max(1, len(val_ids) // batch_size),
    callbacks=[tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=3)]
)
# Out:
# Streaming output truncated to the last 5000 lines.
# ⚠️ Warning: 1042590306_95dea0916c.jpg not found in image_features. Skipping...
# ⚠️ Warning: 207731022_988f6afb35.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1463732130_a754441289.jpg not found in image_features. Skipping...
# ⚠️ Warning: 110595925_f3395c8bd6.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1932314876_9cc46fd054.jpg not found in image_features. Skipping...
# ⚠️ Warning: 162152393_52ecd33fc5.jpg not found in image_features. Skipping...
# ⚠️ Warning: 136552115_6dc3e7231c.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1523800748_a59e980eee.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1439046601_cf110a75a7.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1527297882_dededc7891.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2073105823_6dacade004.jpg not found in image_features. Skipping...
# ⚠️ Warning: 186348874_75b2cf1ec5.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2097420505_439f63c863.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1773928579_5664a810dc.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2086678529_b3301c2d71.jpg not found in image_features. Skipping...
# ⚠️ Warning: 140526326_da07305c1c.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1470061031_4cb59c12a8.jpg not found in image_features. Skipping...
# ⚠️ Warning: 103205630_682ca7285b.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1355703632_5683a4b6fb.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1932161768_996eadac87.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1394927474_0afdd82fc4.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2004674713_2883e63c67.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1095580424_76f0aa8a3e.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1164765687_7aca07bbe7.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1414820925_3504c394e1.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1198194316_543cc7b945.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1472653060_7427d2865a.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1926129518_4350f4f552.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1464120327_d90279ca3a.jpg not found in image_features. Skipping...
# ⚠️ Skipping empty batch...
# ⚠️ Warning: 1436760519_8d6101a0ed.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1348304997_afe60a61df.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1304961697_76b86b0c18.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1000268201_693b08cb0e.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1936215201_d03a75cbba.jpg not found in image_features. Skipping...
# ⚠️ Warning: 170100272_d820db2199.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2097489021_ca1b9f5c3b.jpg not found in image_features. Skipping...
# ⚠️ Warning: 160541986_d5be2ab4c1.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2053777548_108e54c826.jpg not found in image_features. Skipping...
# ⚠️ Warning: 186890605_ddff5b694e.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1333888922_26f15c18c3.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1467533293_a2656cc000.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1597319381_1e80d9e39c.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1022454428_b6b660a67b.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2089555297_95cf001fa7.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2087640654_1a84577a44.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1417031097_ab656bc4bd.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1056359656_662cee0814.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1418019748_51c7d59c11.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1244485675_822e6efe60.jpg not found in image_features. Skipping...
# ⚠️ Warning: 105342180_4d4a40b47f.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1969573381_5ecfae4c80.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1084040636_97d9633581.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1400424834_1c76e700c4.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2056930414_d2b0f1395a.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1776981714_5b224d0f7a.jpg not found in image_features. Skipping...
# ⚠️ Warning: 172097783_292c5413d8.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1178705300_c224d9a4f1.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1015584366_dfcec3c85a.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1251558317_4ef844b775.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1131340021_83f46b150a.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1881494074_1bebd93089.jpg not found in image_features. Skipping...
# ⚠️ Skipping empty batch...
# ⚠️ Warning: 1267711451_e2a754b4f8.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1807169176_7f5226bf5a.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1713248099_d860df4e10.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1015118661_980735411b.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1075867198_27ca2e7efe.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1220401002_3f44b1f3f7.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2044063458_fcc76a7636.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2045023435_181854c013.jpg not found in image_features. Skipping...
# ⚠️ Warning: 102351840_323e3de834.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1413956047_c826f90c8b.jpg not found in image_features. Skipping...
# ⚠️ Warning: 195962284_e57178054a.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1213336750_2269b51397.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1024138940_f1fefbdce1.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1466307485_5e6743332e.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1363843090_9425d93064.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1287475186_2dee85f1a5.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1517721825_10176d0683.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1795151944_d69b82f942.jpg not found in image_features. Skipping...
# ⚠️ Warning: 166654939_80ea4ddbcc.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1860543210_47e94cf652.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2094543127_46d2f1fedf.jpg not found in image_features. Skipping...
# ⚠️ Warning: 160792599_6a7ec52516.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1405221276_21634dcd58.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1338523142_57fce8229b.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1309330801_aeeb23f1ee.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1784309115_0ad6791146.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2056377805_e9a9b3bcf0.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1479679558_d0a01bc62b.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1215334959_b1970965f7.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1557451043_f5c91ff6f4.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1456393634_74022d9056.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2085400856_ae09df33a7.jpg not found in image_features. Skipping...
# ⚠️ Skipping empty batch...
# ⚠️ Warning: 1211015912_9f3ee3a995.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1129704496_4a61441f2c.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1433397131_8634fa6664.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1542033433_5453d4c466.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2067833088_04e84e5bf2.jpg not found in image_features. Skipping...
# ⚠️ Warning: 197504190_fd1fc3d4b7.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1245022983_fb329886dd.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1402640441_81978e32a9.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1115679311_245eff2f4b.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2040941056_7f5fd50794.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1511807116_41c3645e8c.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1928319708_ccf1f4ee72.jpg not found in image_features. Skipping...
# ⚠️ Warning: 142802798_962a4ec5ce.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1332823164_c70a5d930e.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1675679141_36c9bc2969.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1449370354_380c4123c9.jpg not found in image_features. Skipping...
# ⚠️ Warning: 150387174_24825cf871.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1075881101_d55c46bece.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2078311270_f01c9eaf4c.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1810651611_35aae644fb.jpg not found in image_features. Skipping...
# ⚠️ Warning: 106514190_bae200f463.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1501811302_5e723fc529.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1805990081_da9cefe3a5.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1370615506_2b96105ca3.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1119463452_69d4eecd08.jpg not found in image_features. Skipping...
# ⚠️ Warning: 141139674_246c0f90a1.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2051194177_fbeee211e3.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1012212859_01547e3f17.jpg not found in image_features. Skipping...
# ⚠️ Warning: 177302997_5b2d770a0a.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2054869561_ff723e9eab.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1273001772_1585562051.jpg not found in image_features. Skipping...
# ⚠️ Warning: 112178718_87270d9b4d.jpg not found in image_features. Skipping...
# ⚠️ Skipping empty batch...
# ⚠️ Warning: 1355935187_2c99648138.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1312020846_5abb4a9be2.jpg not found in image_features. Skipping...
# ⚠️ Warning: 148512773_bae6901fd6.jpg not found in image_features. Skipping...
# ⚠️ Warning: 150582765_bad8dec237.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1470132731_fa416b7504.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1067180831_a59dc64344.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1814086703_33390d5fc7.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1057089366_ca83da0877.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1153704539_542f7aa3a5.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1580671272_3e99d94305.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1225443522_1633e7121f.jpg not found in image_features. Skipping...
# ⚠️ Warning: 157139628_5dc483e2e4.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2085078076_b9db242d21.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1479028910_3dab3448c8.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2069279767_fb32bfb2de.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1770036088_08abe4f6e9.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1118557877_736f339752.jpg not found in image_features. Skipping...
# ⚠️ Warning: 19212715_20476497a3.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1244306891_8e78ae1620.jpg not found in image_features. Skipping...
# ⚠️ Warning: 189721896_1ffe76d89e.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2097398349_ff178b3f1b.jpg not found in image_features. Skipping...
# ⚠️ Warning: 185972340_781d60ccfd.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2068465241_3bcabacfd7.jpg not found in image_features. Skipping...
# ⚠️ Warning: 123889082_d3751e0350.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1259936608_e3f0064f23.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1406010299_5755339f08.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1415591512_a84644750c.jpg not found in image_features. Skipping...
# ⚠️ Warning: 179009558_69be522c63.jpg not found in image_features. Skipping...
# ⚠️ Warning: 101669240_b2d3e7f17b.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1394620454_bf708cc501.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1222322358_225067636e.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2074146683_7c83167aa1.jpg not found in image_features. Skipping...
# ⚠️ Skipping empty batch...
# ⚠️ Warning: 1389323170_d1c81d6b51.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1732436777_950bcdc9b8.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1517340899_ee1c74a8f6.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1253275679_e955fb7304.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2056041678_d6b5b39b26.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2050067751_22d2763fd2.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1799188614_b5189728ba.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2043520315_4a2c782c90.jpg not found in image_features. Skipping...
# ⚠️ Warning: 171488318_fb26af58e2.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1346529555_e916816cfe.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2029280005_a19609c81a.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1141718391_24164bf1b1.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2036407732_d5a0389bba.jpg not found in image_features. Skipping...
# ⚠️ Warning: 127450902_533ceeddfc.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1357724865_4faf4e1418.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1122944218_8eb3607403.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2089122314_40d5739aef.jpg not found in image_features. Skipping...
# ⚠️ Warning: 109738763_90541ef30d.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1155138244_859fd6e079.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2058472558_7dd5014abd.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1119418776_58e4b93eac.jpg not found in image_features. Skipping...
# ⚠️ Warning: 166507476_9be5b9852a.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1418266617_b32143275b.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2086513494_dbbcb583e7.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1440024115_129212c988.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1569562856_eedb5a0a1f.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2089539651_9e518ec7de.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1508269285_6c5723f67d.jpg not found in image_features. Skipping...
# ⚠️ Warning: 119534510_d52b3781a3.jpg not found in image_features. Skipping...
# ⚠️ Warning: 138705546_be7a6845dd.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1104133405_c04a00707f.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2091171488_c8512fec76.jpg not found in image_features. Skipping...
# ⚠️ Skipping empty batch...
# ⚠️ Warning: 1923476156_e20976b32d.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2068960566_21e85ae0dc.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1042020065_fb3d3ba5ba.jpg not found in image_features. Skipping...
# ⚠️ Warning: 143680442_2f03f76944.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1528205014_1323aa9dfd.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1303550623_cb43ac044a.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1356543628_c13ebe38fb.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1999444757_1b92efb590.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1359101233_16c2c150e3.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1142283988_6b227c5231.jpg not found in image_features. Skipping...
# ⚠️ Warning: 111537217_082a4ba060.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1956944011_c5661d3f22.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1998457059_c9ac9a1e1a.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1055753357_4fa3d8d693.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1007129816_e794419615.jpg not found in image_features. Skipping...
# ⚠️ Warning: 199463720_329a802206.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1576185717_f841ddc3da.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1432342377_3e41603f26.jpg not found in image_features. Skipping...
# ⚠️ Warning: 140526327_3cb984de09.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1420060020_7a6984e2ea.jpg not found in image_features. Skipping...
# ⚠️ Warning: 109260218_fca831f933.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1160034462_16b38174fe.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1425013325_bff69bc9da.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1616016569_673de1d678.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2045562030_654ddea5e5.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1383698008_8ac53ed7ec.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2061944672_0383e65c8a.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1473618073_7db56a5237.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1007320043_627395c3d8.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1167908324_8caab45e15.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2085403342_a17b0654fe.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1536597926_c2e1bc2379.jpg not found in image_features. Skipping...
# ⚠️ Skipping empty batch...
# ⚠️ Warning: 111537222_07e56d5a30.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1573017288_4d481856e2.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1403414927_5f80281505.jpg not found in image_features. Skipping...
# ⚠️ Warning: 159712188_d530dd478c.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1801663973_5ad393caeb.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2061354254_faa5bd294b.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1456630952_dd4778a48f.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1052358063_eae6744153.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1480712062_32a61ad4b7.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1931690777_897a7d8ab6.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1468389504_c724bdcad0.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1402641725_5e027ecaa7.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1392272228_cf104086e6.jpg not found in image_features. Skipping...
# ⚠️ Warning: 109202756_b97fcdc62c.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1263126002_881ebd7ac9.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1067675215_7336a694d6.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1107246521_d16a476380.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1151466868_3bc4d9580b.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1390268323_2c8204e91c.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1541272333_1624b22546.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1386964743_9e80d96b05.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1526325728_74eb4153d8.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2071309418_1d7580b0f0.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1488937076_5baa73fc2a.jpg not found in image_features. Skipping...
# ⚠️ Warning: 189740668_0b045f1ff2.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1434607942_da5432c28c.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1448511770_1a4a9c453b.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1397295388_8a5b6b525d.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1460500597_866fa0c6f3.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1394368714_3bc7c19969.jpg not found in image_features. Skipping...
# ⚠️ Warning: 182493240_40410254b0.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1827560917_c8d3c5627f.jpg not found in image_features. Skipping...
# ⚠️ Skipping empty batch...
# ⚠️ Warning: 1174629344_a2e1a2bdbf.jpg not found in image_features. Skipping...
# ⚠️ Warning: 111537222_07e56d5a30.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1478606153_a7163bf899.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1244140539_da4804d828.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1860543210_47e94cf652.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1252396628_eb81d3905b.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1936215201_d03a75cbba.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1352410176_af6b139734.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1794818900_e0ffdd268e.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1469000260_5d473c8283.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1818403842_553a2a392c.jpg not found in image_features. Skipping...
# ⚠️ Warning: 179009558_69be522c63.jpg not found in image_features. Skipping...
# ⚠️ Warning: 159712188_d530dd478c.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1446933195_8fe9725d62.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2068403258_2669cf9763.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1355935187_2c99648138.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1801663973_5ad393caeb.jpg not found in image_features. Skipping...
# ⚠️ Warning: 135235570_5698072cd4.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1313693129_71d0b21c63.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1775029934_e1e96038a8.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1858963639_4588cd4be9.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1434607942_da5432c28c.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1117972841_2b9261f95f.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1573017288_4d481856e2.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1785138090_76a56aaabc.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1439046601_cf110a75a7.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1523800748_a59e980eee.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1569687608_0e3b3ad044.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1143373711_2e90b7b799.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1122944218_8eb3607403.jpg not found in image_features. Skipping...
# ⚠️ Warning: 172097783_292c5413d8.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1174525839_7c1e6cfa86.jpg not found in image_features. Skipping...
# ⚠️ Skipping empty batch...
# ⚠️ Warning: 1191338263_a4fa073154.jpg not found in image_features. Skipping...
# ⚠️ Warning: 146098876_0d99d7fb98.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1107246521_d16a476380.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1570723692_3a2b064d43.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1569562856_eedb5a0a1f.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1307635496_94442dc21a.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2075493556_b763648389.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1928319708_ccf1f4ee72.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1397887419_e798697b93.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2090327868_9f99e2740d.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2058091220_2087270068.jpg not found in image_features. Skipping...
# ⚠️ Warning: 106514190_bae200f463.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1244485675_822e6efe60.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1427391496_ea512cbe7f.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1003163366_44323f5815.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1007320043_627395c3d8.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2064417101_3b9d817f4a.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1296412797_85b6d2f8d6.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2073105823_6dacade004.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2073756099_7e02c0110c.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2052702658_da1204f6d1.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1454678644_7e5a371301.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1799271536_6e69c8f1dc.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1308617539_54e1a3dfbe.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1402859872_0fc8cf8108.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1425485485_d7c97a5470.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1463732130_a754441289.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1802092493_7b44fdb6b9.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1501985304_8c50093004.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1859726819_9a793b3b44.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1269470943_ba7fc49b4d.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1316247213_1d2c726dd5.jpg not found in image_features. Skipping...
# ⚠️ Skipping empty batch...
# ⚠️ Warning: 1566117559_f5d98fbeb0.jpg not found in image_features. Skipping...
# ⚠️ Warning: 109202756_b97fcdc62c.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2068465241_3bcabacfd7.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1679565118_d36f0d6d52.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1387443857_602ab6f9bf.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1470536919_1f3fd6c65a.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1346051107_9cdc14e070.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1160034462_16b38174fe.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2090545563_a4e66ec76b.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2078311270_f01c9eaf4c.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1392272228_cf104086e6.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1357724865_4faf4e1418.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1304961697_76b86b0c18.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1918573100_d31cbb6b77.jpg not found in image_features. Skipping...
# ⚠️ Warning: 115684808_cb01227802.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1482960952_95f2d419cb.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1287982439_6578006e22.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1248357227_2b4175fc39.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1390268323_2c8204e91c.jpg not found in image_features. Skipping...
# ⚠️ Warning: 160566014_59528ff897.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1998457059_c9ac9a1e1a.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1312227131_771b5ed201.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1904112245_549e47c8aa.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2088460083_42ee8a595a.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1808504612_3508f3c9bb.jpg not found in image_features. Skipping...
# ⚠️ Warning: 195962284_e57178054a.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1131800850_89c7ffd477.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1402843760_d30f1dbf0f.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2017276266_566656c59d.jpg not found in image_features. Skipping...
# ⚠️ Warning: 116409198_0fe0c94f3b.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1957371533_62bc720bac.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1420060020_7a6984e2ea.jpg not found in image_features. Skipping...
# ⚠️ Skipping empty batch...
# ⚠️ Warning: 1295671216_cde1b9c9d1.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1160441615_fe6b3c5277.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1470132731_fa416b7504.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2094323311_27d58b1513.jpg not found in image_features. Skipping...
# ⚠️ Warning: 143688895_e837c3bc76.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1333888922_26f15c18c3.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1460500597_866fa0c6f3.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2045109977_b00ec93491.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1001773457_577c3a7d70.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1874617189_e85d3f4326.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1271960365_e54033f883.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1287475186_2dee85f1a5.jpg not found in image_features. Skipping...
# ⚠️ Warning: 189721896_1ffe76d89e.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1784309115_0ad6791146.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2092419948_eea8001d0f.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1056359656_662cee0814.jpg not found in image_features. Skipping...
# ⚠️ Warning: 106490881_5a2dd9b7bd.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1937262236_cbf5bfa101.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1024138940_f1fefbdce1.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1169307342_e7a4685a5c.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1999444757_1b92efb590.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1937104503_313d22a2d0.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1121416483_c7902d0d49.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1685463722_55843b6d3c.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2087640654_1a84577a44.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1020651753_06077ec457.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1413956047_c826f90c8b.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1456630952_dd4778a48f.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1245022983_fb329886dd.jpg not found in image_features. Skipping...
# ⚠️ Warning: 109738763_90541ef30d.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2086534745_1e4ab80078.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1659396176_ced00a549f.jpg not found in image_features. Skipping...
# ⚠️ Skipping empty batch...
# ⚠️ Warning: 2046222127_a6f300e202.jpg not found in image_features. Skipping...
# ⚠️ Warning: 146577645_91b570c0d0.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1075867198_27ca2e7efe.jpg not found in image_features. Skipping...
# ⚠️ Warning: 197504190_fd1fc3d4b7.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2030781555_b7ff7be28f.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1417882092_c94c251eb3.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1285067106_2adc307240.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1884727806_d84f209868.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1947351225_288d788983.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1812525037_528465037c.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1378557186_4bd1da6834.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2084103826_ffd76b1e3e.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1683444418_815f660379.jpg not found in image_features. Skipping...
# ⚠️ Warning: 191592626_477ef5e026.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1335617803_4fbc03dab0.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1428641354_f7453afbea.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1527297882_dededc7891.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1576185717_f841ddc3da.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1130017585_1a219257ac.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1522787272_5a31497ef2.jpg not found in image_features. Skipping...
# ⚠️ Warning: 123997871_6a9ca987b1.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1388970365_162edcceb4.jpg not found in image_features. Skipping...
# ⚠️ Warning: 191003284_1025b0fb7d.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2096771662_984441d20d.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1975531316_8b00eeaaf7.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1222322358_225067636e.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1432179046_8e3d75cf81.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2061397486_53a61e17c5.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2097398349_ff178b3f1b.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1079274291_9aaf896cc1.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1394396709_65040d97ab.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1142847777_2a0c1c2551.jpg not found in image_features. Skipping...
# ⚠️ Skipping empty batch...
# ⚠️ Warning: 141140165_9002a04f19.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1263801010_5c74bf1715.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1481062342_d9e34366c4.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1301140633_046e4e8010.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2090387793_274ab4cf7d.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2041867793_552819a40b.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2034553054_b00c166895.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1795151944_d69b82f942.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2092870249_90e3f1855b.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1917203130_fcaff8b10e.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1808007704_ee8a93abb4.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1088767354_2acee738cf.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1859941832_7faf6e5fa9.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1151466868_3bc4d9580b.jpg not found in image_features. Skipping...
# ⚠️ Warning: 107582366_d86f2d3347.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1547883892_e29b3db42e.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1579287915_4257c54451.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1819261140_6c022f4b1d.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1237985362_dbafc59280.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1355833561_9c43073eda.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1346529555_e916816cfe.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1428681303_04213524e3.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2089350172_dc2cf9fcf6.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1206506157_c7956accd5.jpg not found in image_features. Skipping...
# ⚠️ Warning: 104136873_5b5d41be75.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1304100320_c8990a1539.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2056377805_e9a9b3bcf0.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2085403342_a17b0654fe.jpg not found in image_features. Skipping...
# ⚠️ Warning: 136886677_6026c622eb.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1159574340_99ba8c3c59.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2061144717_5b3a1864f0.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1969573381_5ecfae4c80.jpg not found in image_features. Skipping...
# ⚠️ Skipping empty batch...
# ⚠️ Warning: 1572286502_64e5c4b920.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1721637099_93e9ec2a2f.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1067180831_a59dc64344.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1626754053_81126b67b6.jpg not found in image_features. Skipping...
# ⚠️ Warning: 105342180_4d4a40b47f.jpg not found in image_features. Skipping...
# ⚠️ Warning: 140430106_2978fda105.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1433088025_bce2cb69f8.jpg not found in image_features. Skipping...
# ⚠️ Warning: 103195344_5d2dc613a3.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1357689954_72588dfdc4.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2086678529_b3301c2d71.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2083778090_3aecaa11cc.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1394368714_3bc7c19969.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1396064003_3fd949c9dd.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2051194177_fbeee211e3.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2058124718_89822bc96e.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1358089136_976e3d2e30.jpg not found in image_features. Skipping...
# ⚠️ Warning: 191003287_2915c11d8e.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1464120327_d90279ca3a.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2085255128_61224cc47f.jpg not found in image_features. Skipping...
# ⚠️ Warning: 141755292_7a0b3364cf.jpg not found in image_features. Skipping...
# ⚠️ Warning: 181777261_84c48b31cb.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1430154945_71bbaa094a.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1670592963_39731a3dac.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1675679141_36c9bc2969.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2074146683_7c83167aa1.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1187435567_18173c148b.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1386964743_9e80d96b05.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1989145280_3b54452188.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1334892555_1beff092c3.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1440024115_129212c988.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1776981714_5b224d0f7a.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1474474514_b3eb492722.jpg not found in image_features. Skipping...
# ⚠️ Skipping empty batch...
# ⚠️ Warning: 1597319381_1e80d9e39c.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1289142574_2bd6a082dd.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1312954382_cf6d70d63a.jpg not found in image_features. Skipping...
# ⚠️ Warning: 199809190_e3f6bbe2bc.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1002674143_1b742ab4b8.jpg not found in image_features. Skipping...
# ⚠️ Warning: 127488876_f2d2a89588.jpg not found in image_features. Skipping...
# ⚠️ Warning: 131632409_4de0d4e710.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1509786421_f03158adfc.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1356796100_b265479721.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1468962616_5803b4397f.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1189977786_4f5aaed773.jpg not found in image_features. Skipping...
# ⚠️ Warning: 161669933_3e7d8c7e2c.jpg not found in image_features. Skipping...
# ⚠️ Warning: 17273391_55cfc7d3d4.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1459032057_97e73ed6ab.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1332823164_c70a5d930e.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2004674713_2883e63c67.jpg not found in image_features. Skipping...
# ⚠️ Warning: 185057637_e8ada37343.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1478294229_7e1c822fea.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2052202553_373dad145b.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1517807181_ca6588f2a0.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2089442007_6fc798548c.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1732436777_950bcdc9b8.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2076428547_738e0a132f.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1115565519_d976d4b1f1.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2089426086_7acc98a3a8.jpg not found in image_features. Skipping...
# ⚠️ Warning: 200771289_31902164a7.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2082005167_a0d6a70020.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2074764331_90a9962b52.jpg not found in image_features. Skipping...
# ⚠️ Warning: 109202801_c6381eef15.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2076906555_c20dc082db.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1198194316_543cc7b945.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1574401950_6bedc0d29b.jpg not found in image_features. Skipping...
# ⚠️ Skipping empty batch...
# ⚠️ Warning: 1303727828_d1052ee341.jpg not found in image_features. Skipping...
# ⚠️ Warning: 132489044_3be606baf7.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1895768965_43cd9d164f.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1562478333_43d13e5427.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2061354254_faa5bd294b.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1303335399_b3facd47ab.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1095580424_76f0aa8a3e.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1467533293_a2656cc000.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1466479163_439db855af.jpg not found in image_features. Skipping...
# ⚠️ Warning: 166507476_9be5b9852a.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1355945307_f9e01a9a05.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1499554025_a8ffe0e479.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2045562030_654ddea5e5.jpg not found in image_features. Skipping...
# ⚠️ Warning: 136644885_f7d2bbf546.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1231229740_8dcbf80bfb.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2045928594_92510c1c2a.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1236951314_0308dc4138.jpg not found in image_features. Skipping...
# ⚠️ Warning: 191003283_992257f835.jpg not found in image_features. Skipping...
# ⚠️ Warning: 166654939_80ea4ddbcc.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2086532897_b8714f2237.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1141739219_2c47195e4c.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1341787777_4f1ebb1793.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1398873613_7e3174dd6c.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1148238960_f8cacec2fc.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1067790824_f3cc97239b.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1689658980_0074d81d28.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1290894194_8a4ffdc7eb.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1262583859_653f1469a9.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1294578091_2ad02fea91.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1130401779_8c30182e3e.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1770036088_08abe4f6e9.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1287920676_d21a0b289b.jpg not found in image_features. Skipping...
# ⚠️ Skipping empty batch...
# ⚠️ Warning: 2092177624_13ab757e8b.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1213336750_2269b51397.jpg not found in image_features. Skipping...
# ⚠️ Warning: 140526327_3cb984de09.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1305564994_00513f9a5b.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1542033433_5453d4c466.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1389323170_d1c81d6b51.jpg not found in image_features. Skipping...
# ⚠️ Warning: 143680442_2f03f76944.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1348304997_afe60a61df.jpg not found in image_features. Skipping...
# ⚠️ Warning: 118187095_d422383c81.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1419385780_1383ec7ba9.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1408958345_68eea9a4e4.jpg not found in image_features. Skipping...
# ⚠️ Warning: 172092464_d9eb4f4f2f.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2029280005_a19609c81a.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1119463452_69d4eecd08.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1453366750_6e8cf601bf.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1094462889_f9966dafa6.jpg not found in image_features. Skipping...
# ⚠️ Warning: 143552829_72b6ba49d4.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1526181215_c1a94325ae.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2068960566_21e85ae0dc.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1597557856_30640e0b43.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1552065993_b4dcd2eadf.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1400424834_1c76e700c4.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1204996216_71d7519d9a.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1394620454_bf708cc501.jpg not found in image_features. Skipping...
# ⚠️ Warning: 129599450_cab4e77343.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1579798212_d30844b4c5.jpg not found in image_features. Skipping...
# ⚠️ Warning: 141755290_4b954529f3.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1511807116_41c3645e8c.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2089542487_b4c1ee7025.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1980882959_9a161f3469.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1428578577_82864facae.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1042020065_fb3d3ba5ba.jpg not found in image_features. Skipping...
# ⚠️ Skipping empty batch...
# ⚠️ Warning: 1129704496_4a61441f2c.jpg not found in image_features. Skipping...
# ⚠️ Warning: 140526326_da07305c1c.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1765164972_92dac06fa9.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1801874841_4c12055e2f.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1562392511_522a26063b.jpg not found in image_features. Skipping...
# ⚠️ Warning: 191003285_edd8d0cf58.jpg not found in image_features. Skipping...
# ⚠️ Warning: 121800200_bef08fae5f.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2009636597_e3f4fe19fb.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1460352062_d64fb633e0.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2003663004_5b70920a98.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1777816180_08d7e8063b.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1368338041_6b4077ca98.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1962729184_6996e128e7.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1443807993_aebfb2784a.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1541272333_1624b22546.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1807169176_7f5226bf5a.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2064780645_8f28a1529f.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1449692616_60507875fb.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1235685934_be89b231fb.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2088910854_c6f8d4f5f9.jpg not found in image_features. Skipping...
# ⚠️ Warning: 138705546_be7a6845dd.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1167669558_87a8a467d6.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1557451043_f5c91ff6f4.jpg not found in image_features. Skipping...
# ⚠️ Warning: 138718600_f430ebca17.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1363843090_9425d93064.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1022975728_75515238d8.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1397923690_d3bf1f799e.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2054308369_f9c6ec7815.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2071309418_1d7580b0f0.jpg not found in image_features. Skipping...
# ...
# ⚠️ Warning: 1389264266_8170bc1c54.jpg not found in image_features. Skipping...
# ⚠️ Warning: 103205630_682ca7285b.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1084040636_97d9633581.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1215334959_b1970965f7.jpg not found in image_features. Skipping...
# ⚠️ Warning: 140526326_da07305c1c.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1511807116_41c3645e8c.jpg not found in image_features. Skipping...
# ⚠️ Warning: 191003287_2915c11d8e.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1775029934_e1e96038a8.jpg not found in image_features. Skipping...
# ⚠️ Warning: 186348874_75b2cf1ec5.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2064780645_8f28a1529f.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1187435567_18173c148b.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1307635496_94442dc21a.jpg not found in image_features. Skipping...
# ⚠️ Warning: 146098876_0d99d7fb98.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1597319381_1e80d9e39c.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1082379191_ec1e53f996.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2054308369_f9c6ec7815.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1464120327_d90279ca3a.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1459250022_bf1eddad11.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2054869561_ff723e9eab.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2094543127_46d2f1fedf.jpg not found in image_features. Skipping...
# ⚠️ Skipping empty batch...
# ⚠️ Warning: 1449692616_60507875fb.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1472053993_bed67a3ba7.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2050067751_22d2763fd2.jpg not found in image_features. Skipping...
# ⚠️ Warning: 138705546_be7a6845dd.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1378557186_4bd1da6834.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1473618073_7db56a5237.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2052702658_da1204f6d1.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1514957266_a19827c538.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1236951314_0308dc4138.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1865794069_6e3a1e57bb.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1408958345_68eea9a4e4.jpg not found in image_features. Skipping...
# ⚠️ Warning: 141755292_7a0b3364cf.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1330645772_24f831ff8f.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1400424834_1c76e700c4.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1356796100_b265479721.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1542033433_5453d4c466.jpg not found in image_features. Skipping...
# ⚠️ Warning: 134894450_dadea45d65.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1481062342_d9e34366c4.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1342780478_bacc32344d.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2068403258_2669cf9763.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1095980313_3c94799968.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1056338697_4f7d7ce270.jpg not found in image_features. Skipping...
# ⚠️ Warning: 140430106_2978fda105.jpg not found in image_features. Skipping...
# ⚠️ Warning: 19212715_20476497a3.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1801663973_5ad393caeb.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2060031241_a3ae7a06bb.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2003663004_5b70920a98.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1962729184_6996e128e7.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1777816180_08d7e8063b.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2083434441_a93bc6306b.jpg not found in image_features. Skipping...
# ⚠️ Warning: 206087108_d4557d38ee.jpg not found in image_features. Skipping...
# ⚠️ Warning: 113678030_87a6a6e42e.jpg not found in image_features. Skipping...
# ⚠️ Skipping empty batch...
# ⚠️ Warning: 1463732130_a754441289.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1131800850_89c7ffd477.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1432342377_3e41603f26.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1389323170_d1c81d6b51.jpg not found in image_features. Skipping...
# ⚠️ Warning: 181415975_2627aa6668.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1714316707_8bbaa2a2ba.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1461653394_8ab96aae63.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2073964624_52da3a0fc4.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2084103826_ffd76b1e3e.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1470132731_fa416b7504.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2021671653_567395c7cf.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1189977786_4f5aaed773.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1975171469_84e425f61b.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1773928579_5664a810dc.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1397923690_d3bf1f799e.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1957371533_62bc720bac.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1096395242_fc69f0ae5a.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1529044279_4922ead27c.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2029280005_a19609c81a.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1244140539_da4804d828.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1798215547_ef7ad95be8.jpg not found in image_features. Skipping...
# ⚠️ Warning: 172097782_f0844ec317.jpg not found in image_features. Skipping...
# ⚠️ Warning: 191003284_1025b0fb7d.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1659358141_0433c9bf99.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1095590286_c654f7e5a9.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1234817607_924893f6e1.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2067362863_59577f9d4d.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1685990174_09c4fb7df8.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1528205014_1323aa9dfd.jpg not found in image_features. Skipping...
# ⚠️ Warning: 121800200_bef08fae5f.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1837976956_3c45d0f9b8.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2076865206_53918c820c.jpg not found in image_features. Skipping...
# ⚠️ Skipping empty batch...
# ⚠️ Warning: 1026685415_0431cbf574.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2064417101_3b9d817f4a.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1713248047_d03721456d.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1468962616_5803b4397f.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1167908324_8caab45e15.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1055753357_4fa3d8d693.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1488937076_5baa73fc2a.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1277185009_06478dd457.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2089555297_95cf001fa7.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1434607942_da5432c28c.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1131340021_83f46b150a.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1362128028_8422d53dc4.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2017276266_566656c59d.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1263126002_881ebd7ac9.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1562478333_43d13e5427.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1461667284_041c8a2475.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1370773415_967b1ffde1.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1355833561_9c43073eda.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2085078076_b9db242d21.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1479028910_3dab3448c8.jpg not found in image_features. Skipping...
# ⚠️ Warning: 111537222_07e56d5a30.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1368338041_6b4077ca98.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1321723162_9d4c78b8af.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1770036088_08abe4f6e9.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1428641354_f7453afbea.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1936215201_d03a75cbba.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1453366750_6e8cf601bf.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1303548017_47de590273.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1032122270_ea6f0beedb.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2046222127_a6f300e202.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2070798293_6b9405e04d.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1808504612_3508f3c9bb.jpg not found in image_features. Skipping...
# ⚠️ Skipping empty batch...
# ⚠️ Warning: 1390268323_2c8204e91c.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1313961775_824b87d155.jpg not found in image_features. Skipping...
# ⚠️ Warning: 181777261_84c48b31cb.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1303727828_d1052ee341.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1449625950_fc9a8d02d9.jpg not found in image_features. Skipping...
# ⚠️ Warning: 155221027_b23a4331b7.jpg not found in image_features. Skipping...
# ⚠️ Warning: 138718600_f430ebca17.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1526181215_c1a94325ae.jpg not found in image_features. Skipping...
# ⚠️ Warning: 110595925_f3395c8bd6.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1547883892_e29b3db42e.jpg not found in image_features. Skipping...
# ⚠️ Warning: 146577646_9e64b8c2dc.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1024138940_f1fefbdce1.jpg not found in image_features. Skipping...
# ⚠️ Warning: 172097783_292c5413d8.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1130401779_8c30182e3e.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1287475186_2dee85f1a5.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1398606571_f543f7698a.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1778020185_1d44c04dae.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1675679141_36c9bc2969.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1350811702_2ce7cfd0c5.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1689658980_0074d81d28.jpg not found in image_features. Skipping...
# ⚠️ Warning: 185972340_781d60ccfd.jpg not found in image_features. Skipping...
# ⚠️ Warning: 112243673_fd68255217.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2097420505_439f63c863.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1554713437_61b64527dd.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2009636597_e3f4fe19fb.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2088460083_42ee8a595a.jpg not found in image_features. Skipping...
# ⚠️ Warning: 131632409_4de0d4e710.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1969573381_5ecfae4c80.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1095476286_87d4f8664e.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1110208841_5bb6806afe.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1299459550_1fd5594fa2.jpg not found in image_features. Skipping...
# ⚠️ Warning: 182493240_40410254b0.jpg not found in image_features. Skipping...
# ⚠️ Skipping empty batch...
# ⚠️ Warning: 2074146683_7c83167aa1.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1622619190_d0b51aff28.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1294578091_2ad02fea91.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2036407732_d5a0389bba.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1309330801_aeeb23f1ee.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1229756013_94663527d7.jpg not found in image_features. Skipping...
# ⚠️ Warning: 203114209_e4cd71a6b7.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2038662925_f4fa8c2534.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1267711451_e2a754b4f8.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1370615506_2b96105ca3.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1809758121_96026913bb.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1434005938_ad75c8598c.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1072153132_53d2bb1b60.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1805990081_da9cefe3a5.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1244485675_822e6efe60.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1197800988_7fb0ca4888.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1932314876_9cc46fd054.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1159574340_99ba8c3c59.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1884065356_c6c34b4568.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1030985833_b0902ea560.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1355935187_2c99648138.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1423997242_ea2189ec5e.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1052358063_eae6744153.jpg not found in image_features. Skipping...
# ⚠️ Warning: 102351840_323e3de834.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1384292980_4022a7520c.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1053804096_ad278b25f1.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1570723692_3a2b064d43.jpg not found in image_features. Skipping...
# ⚠️ Warning: 201682811_105241dee3.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1131804997_177c3c0640.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1937104503_313d22a2d0.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1799188614_b5189728ba.jpg not found in image_features. Skipping...
# ⚠️ Warning: 209605542_ca9cc52e7b.jpg not found in image_features. Skipping...
# ⚠️ Skipping empty batch...
# ⚠️ Warning: 1860543210_47e94cf652.jpg not found in image_features. Skipping...
# ⚠️ Warning: 143688895_e837c3bc76.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1579206585_5ca6a24db0.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1160441615_fe6b3c5277.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1808007704_ee8a93abb4.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2070831523_5035d5537e.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1810651611_35aae644fb.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1177994172_10d143cb8d.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2088120475_d6318364f5.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1998457059_c9ac9a1e1a.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1067180831_a59dc64344.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2097489021_ca1b9f5c3b.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1515883224_14e36a53c7.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1467533293_a2656cc000.jpg not found in image_features. Skipping...
# ⚠️ Warning: 2085403342_a17b0654fe.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1357724865_4faf4e1418.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1956944011_c5661d3f22.jpg not found in image_features. Skipping...
# ⚠️ Warning: 150582765_bad8dec237.jpg not found in image_features. Skipping...
# ⚠️ Warning: 114051287_dd85625a04.jpg not found in image_features. Skipping...
# ⚠️ Warning: 1255504166_f2437febcb.jpg not found in image_features. Skipping...

# %%
# Load Best Model
model.load_weights("best_model.h5")

# BLEU Score Evaluation
def evaluate_bleu(model, image_features, captions, tokenizer, max_length):
    actual, predicted = [], []
    for img_id in random.sample(list(image_features.keys()), 100):
        feature = image_features[img_id]
        y_pred = generate_caption(model, feature, tokenizer, max_length)
        actual.append([caption.split() for caption in captions[img_id]])
        predicted.append(y_pred.split())
    bleu_score = corpus_bleu(actual, predicted)
    print(f"BLEU Score: {bleu_score:.4f}")

def generate_caption(model, image_feature, tokenizer, max_length):
    in_text = 'startseq'
    for _ in range(max_length):
        seq = tokenizer.texts_to_sequences([in_text])[0]
        seq = pad_sequences([seq], maxlen=max_length)
        y_pred = model.predict([image_feature.reshape(1, 2048), seq], verbose=0)
        y_pred = np.argmax(y_pred)
        word = {index: word for word, index in tokenizer.word_index.items()}.get(y_pred)
        if word is None or word == 'endseq':
            break
        in_text += ' ' + word
    return in_text

evaluate_bleu(model, image_features, captions, tokenizer, max_length)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-aa296726c78e> in <cell line: 0>()
#       1 # Load Best Model
# ----> 2 model.load_weights("best_model.h5")
#       3
#       4 # BLEU Score Evaluation
#       5 def evaluate_bleu(model, image_features, captions, tokenizer, max_length):
#
# NameError: name 'model' is not defined

# %%
# Test with GIKI Images
def load_giki_image(image_path):
    image = cv2.imread(image_path)
    image = cv2.resize(image, (299, 299))  # Resize for InceptionV3
    image = image / 255.0
    return np.expand_dims(image, axis=0)

def extract_features(image_path, model):
    image = load_giki_image(image_path)
    feature = model.predict(image)
    return feature.reshape(-1)

cnn_model = tf.keras.applications.InceptionV3(include_top=False, pooling="avg")
giki_images = ["giki1.jpg", "giki2.jpg", "giki3.jpg"]

for img_path in giki_images:
    feature = extract_features(img_path, cnn_model)
    caption = generate_caption(model, feature, tokenizer, max_length)
    print(f"Generated Caption: {caption}")

    # Convert caption to voice
    tts = gTTS(text=caption, lang='en')
    audio_path = img_path.replace('.jpg', '.mp3')
    tts.save(audio_path)
    os.system(f"mpg321 {audio_path}")

    # Display Image
    image = cv2.imread(img_path)
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.axis('off')
    plt.title(caption)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-db6a5800f8ef> in <cell line: 0>()
#      11     return feature.reshape(-1)
#      12
# ---> 13 cnn_model = tf.keras.applications.InceptionV3(include_top=False, pooling="avg")
#      14 giki_images = ["giki1.jpg", "giki2.jpg", "giki3.jpg"]
#      15
#
# NameError: name 'tf' is not defined
